# %%
# %matplotlib inline
import pandas as pd
data = pd.read_csv('sp500.csv', index_col='Date', parse_dates=['Date'])
data['SMA'] = data['SP500'].rolling(200).mean()
data['SMA2'] = data['SP500'].rolling(100).mean()
data.plot()
